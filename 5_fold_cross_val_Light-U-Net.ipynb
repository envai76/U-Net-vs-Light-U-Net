# %% [markdown]
# # Importing required libs

# %%
import tensorflow as tf
import time
# Check TensorFlow version
print(f"TensorFlow version: {tf.__version__}")

# List available physical devices
physical_devices = tf.config.list_physical_devices('GPU')
print("Available GPUs:")
for device in physical_devices:
    print(device)
    
# Check if TensorFlow is using the GPU
if tf.test.is_built_with_cuda():
    print("TensorFlow is built with CUDA")
    if len(physical_devices) > 0:
        print("TensorFlow is using the GPU")
    else:
        print("TensorFlow is not using the GPU, but it is available")
else:
    print("TensorFlow is not built with CUDA")
# Out:
# TensorFlow version: 2.6.0
# Available GPUs:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# TensorFlow is built with CUDA
# TensorFlow is using the GPU

# %%
# %run generator.ipynb
# %run model.ipynb

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.callbacks import ModelCheckpoint,Callback,LearningRateScheduler , TensorBoard
from tensorflow import keras
from tensorflow.keras.optimizers import SGD, RMSprop
from tensorflow.keras import backend as K
import os
import datetime
import numpy as np
import shutil
# from skimage import morphology, feature, segmentation, measure, io, color
# from skimage.filters import sobel
import matplotlib.pyplot as plt
import cv2
import pdb
import imageio
from scipy import misc
import scipy.ndimage as ndimage
import warnings
warnings.filterwarnings('ignore')
# from google.colab.patches import cv2_imshow  # Only required in Google Colab
import numpy as np
import tensorflow as tf
import datetime
import time
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, Callback
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K

# %% [markdown]
# # Visualization methods

# %%
def to_three_channels(img):
  return np.squeeze(np.stack((img,img,img), 2))

def show_sample(img, anno, label):
  squeezed =  np.squeeze(anno)

  figure, axis = plt.subplots(1,3)
  axis[0].imshow(img)
  axis[1].imshow(squeezed)
  squeezed =  np.squeeze(label)
  axis[2].imshow(squeezed)




def show_batch(img, label):
  show_sample(img[0,:,:,:],label[0,:,:,:])

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

def save_sample(img, label , gt,  folder_name , sample_file_name, lable_type , counts):
    folder_name = folder_name + str(sample_file_name).split("dic.png")[0] + "/"
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
        print(folder_name)
        output_path = os.path.join(folder_name, 'counts.txt')
        with open(output_path, 'w') as file:
            file.write(str(counts) + '\n')
    
    
    squeezed_label =  np.squeeze(label)
    squeezed_gt =  np.squeeze(gt)
    

    # Ensure images are in the correct range
    if img.dtype == np.float64 or img.dtype == np.float32:
        img = np.interp(img, (img.min(), img.max()), (0, 1))
    
    if squeezed_label.dtype == np.float64 or squeezed_label.dtype == np.float32:
        squeezed_label = np.interp(squeezed_label, (squeezed_label.min(), squeezed_label.max()), (0, 1))
    if squeezed_gt.dtype == np.float64 or squeezed_gt.dtype == np.float32:
        squeezed_gt = np.interp(squeezed_gt, (squeezed_gt.min(), squeezed_gt.max()), (0, 1))
    

    # Save the first image
    fig, ax = plt.subplots()
    ax.imshow(img)
    # ax.set_title('Image')
    plt.axis('off')  # Turn off the axis
    output_path = os.path.join(folder_name, 'image_1.jpg')
    plt.savefig(output_path, bbox_inches='tight', pad_inches=0)  # Save without white spaces
    plt.close(fig)  # Close the figure to free up memory
    
    
    # Save the third image
    fig, ax = plt.subplots()
    ax.imshow(squeezed_label)
    # ax.set_title('Squeezed Label')
    plt.axis('off')  # Turn off the axis
    output_path = os.path.join(folder_name, 'image_pr_'+lable_type+'.jpg')
    plt.savefig(output_path, bbox_inches='tight', pad_inches=0)  # Save without white spaces
    plt.close(fig)  # Close the figure to free up memory

     # Save the third image
    fig, ax = plt.subplots()
    ax.imshow(squeezed_gt)
    # ax.set_title('Squeezed gt')
    plt.axis('off')  # Turn off the axis
    output_path = os.path.join(folder_name, 'image_gt_'+lable_type+'.jpg')
    plt.savefig(output_path, bbox_inches='tight', pad_inches=0)  # Save without white spaces
    plt.close(fig)  # Close the figure to free up memory
    # plt.show()


def show_save_all_sample(img , c_label , c_gt , r_label , r_gt , folder_name , sample_file_name , counts ):
    
    squeezed_r_label = np.squeeze(r_label)
    squeezed_c_label = np.squeeze(c_label)
    # Ensure images are in the correct range
    if img.dtype == np.float64 or img.dtype == np.float32:
        img = np.interp(img, (img.min(), img.max()), (0, 1))
   
    if squeezed_c_label.dtype == np.float64 or squeezed_c_label.dtype == np.float32:
        squeezed_c_label = np.interp(squeezed_c_label, (squeezed_c_label.min(), squeezed_c_label.max()), (0, 1))

    
    if squeezed_r_label.dtype == np.float64 or squeezed_c_label.dtype == np.float32:
        squeezed_r_label = np.interp(squeezed_r_label, (squeezed_r_label.min(), squeezed_r_label.max()), (0, 1))
        
   
    figure, axis = plt.subplots(1, 5, figsize=(15, 5))
    axis[0].imshow(img)
    axis[0].set_title('Image')
    axis[0].axis('off')
    
  
    axis[1].imshow(c_gt)
    axis[1].set_title('Centroids Ground Truth')
    axis[1].axis('off')
    
    axis[2].imshow(squeezed_c_label)
    axis[2].set_title('Centroids Prediction')
    axis[2].axis('off')

    
                 
    axis[3].imshow(r_gt)
    axis[3].set_title('Regions Ground Truth')
    axis[3].axis('off')
    
    axis[4].imshow(squeezed_r_label)
    axis[4].set_title('Regions Prediction')
    axis[4].axis('off')

    plt.show()
    save_sample(img, c_label ,c_gt, folder_name , sample_file_name, "centroids" , counts)
    save_sample(img, r_label ,r_gt, folder_name , sample_file_name, "regions" , counts )

# %% [markdown]
# # preparing the dataset

# %%
# Setting dimensions
image_height = 256
image_width = 256

# %% [markdown]
# ## Generating DIC like images

# %%
base_address= 'C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper'

# %%
folder_path = base_address +'/real_dataset/data_80_cells/'
output_folder_path = base_address+'/real_dataset/data_80_dics/'

files = os.listdir(folder_path)

for file in files:
    # Create the full file path
    print(os.path.join(folder_path, file))
    if 'ipynb_checkpoints' not in os.path.join(folder_path, file) :

        file_path = os.path.join(folder_path, file)
        # Load the input image
        input_image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
    
        # Apply gradient filter to find edges of the cells
        gradient_x = cv2.Sobel(input_image, cv2.CV_64F, 1, 0, ksize=3)
        gradient_y = cv2.Sobel(input_image, cv2.CV_64F, 0, 1, ksize=3)
        gradient_magnitude = cv2.magnitude(gradient_x, gradient_y)
    
        # Normalize gradient magnitude to [0, 255]
        gradient_magnitude = cv2.normalize(gradient_magnitude, None, 0, 255, cv2.NORM_MINMAX)
    
        # Simulate shading
        shading_strength = 0.5 # Adjust this parameter to control shading strength
        shading = np.ones_like(input_image, dtype=np.float64) * 127
        shading += shading_strength * gradient_magnitude
    
        # Add shading to the input image
        output_image = cv2.add(input_image, shading.astype(np.uint8))
    
        new_file_name = file.replace('cell.png', '_dic.png')
    
        output_file_path = os.path.join(output_folder_path, new_file_name)
        print(output_file_path)
        cv2.imwrite(output_file_path, output_image)
# Out:
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/.ipynb_checkpoints
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/001cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/001_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/002cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/002_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/003cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/003_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/004cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/004_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/005cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/005_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/006cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/006_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/007cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/007_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/008cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/008_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/009cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/009_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/010cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/010_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/011cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/011_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/012cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/012_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/013cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/013_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/014cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/014_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/015cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/015_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/016cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/016_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/017cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/017_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/018cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/018_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/019cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/019_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/020cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/020_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/021cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/021_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/022cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/022_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/023cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/023_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/024cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/024_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/025cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/025_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/026cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/026_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/027cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/027_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/028cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/028_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/029cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/029_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/030cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/030_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/031cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/031_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/032cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/032_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/033cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/033_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/034cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/034_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/035cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/035_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/036cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/036_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/037cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/037_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/038cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/038_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/039cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/039_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/040cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/040_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/041cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/041_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/042cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/042_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/043cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/043_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/044cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/044_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/045cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/045_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/046cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/046_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/047cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/047_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/048cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/048_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/049cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/049_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/050cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/050_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/051cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/051_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/052cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/052_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/053cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/053_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/054cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/054_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/055cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/055_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/056cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/056_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/057cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/057_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/058cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/058_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/059cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/059_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/060cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/060_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/061cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/061_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/062cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/062_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/063cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/063_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/064cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/064_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/065cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/065_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/066cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/066_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/067cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/067_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/068cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/068_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/069cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/069_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/070cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/070_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/071cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/071_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/072cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/072_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/073cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/073_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/074cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/074_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/075cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/075_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/076cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/076_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/077cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/077_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/078cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/078_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/079cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/079_dic.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_cells/080cell.png
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper/real_dataset/data_80_dics/080_dic.png

# %% [markdown]
# ## Generating regions images

# %%
centroids_path = base_address+ './real_dataset/data_80_dots/'
regions_path =base_address+'./real_dataset/data_80_regions/'

data = []
anno = []
img_labels=[]
def show_maped_centroids(centroids_path):
  imList = os.listdir(centroids_path)
  for i in range(len(imList)):
          # read the original image
          binary_image = cv2.imread( os.path.join(centroids_path, imList[i]) , cv2.IMREAD_GRAYSCALE)
          print(binary_image.shape)
          black_image = np.zeros((image_height, image_width, 1), dtype=np.uint8)

          white_pixel_locations = np.where(binary_image >0)

          for y, x in zip(*white_pixel_locations):
              cv2.circle(black_image, (x, y), 7 , 255, -1)  # Draw a red circle at each white pixel location
              cv2.circle(binary_image, (x, y), 7 , 255, -1)  # Draw a red circle at each white pixel location

          # Show the result image
          # cv2_imshow(black_image)
          # cv2_imshow(binary_image)
          cv2.imwrite( str(regions_path+ str( imList[i][:3] )+ 'regions.png')  , black_image )

          print(str(os.path.join(centroids_path, imList[i][:3])) , "\n\n\n"  )
show_maped_centroids(centroids_path)
# Out:
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/001
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/002
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/003
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/004
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/005
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/006
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/007
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/008
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/009
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/010
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/011
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/012
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/013
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/014
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/015
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/016
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/017
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/018
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/019
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/020
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/021
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/022
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/023
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/024
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/025
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/026
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/027
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/028
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/029
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/030
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/031
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/032
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/033
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/034
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/035
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/036
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/037
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/038
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/039
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/040
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/041
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/042
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/043
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/044
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/045
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/046
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/047
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/048
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/049
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/050
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/051
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/052
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/053
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/054
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/055
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/056
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/057
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/058
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/059
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/060
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/061
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/062
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/063
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/064
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/065
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/066
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/067
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/068
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/069
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/070
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/071
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/072
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/073
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/074
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/075
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/076
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/077
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/078
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/079
#
#
#
# (256, 256)
# C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper./real_dataset/data_80_dots/080

# %% [markdown]
# # Light-U-Net Centroids

# %%
# !pip install scikit-learn --no-deps
# !pip install joblib --no-deps
# !pip install threadpoolctl --no-deps
# Out:
# Collecting threadpoolctl
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl
# Successfully installed threadpoolctl-3.5.0

# %%
# Assuming the model building function is defined as `buildModel_Light_U_net`
# Example: model = buildModel_Light_U_net(input_dim=(256, 256, 3))

def step_decay(epoch):
    step = 16
    lrate = 1e0
    num = epoch // step
    if num % 3 == 0:
        lrate = 1e-3
    elif num % 3 == 1:
        lrate = 1e-4
    else:
        lrate = 1e-5
    print('Learning rate for epoch {} is {}.'.format(epoch+1, lrate))
    return float(lrate)

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

# 5-Fold Cross Validation implementation
def train_with_kfold(data, anno, n_splits=5):
    # Step 1: Preprocessing data (Standardization)
    mean = np.mean(data)
    std = np.std(data)
    data_ = (data - mean) / std

    # Initialize KFold
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold_results = []  # To store results for each fold
    durations=[]
    fold = 1

    for train_index, val_index in kf.split(data_):
        print(f"Training fold {fold}/{n_splits}")

        # Split data into training and validation sets based on the current fold
        train_data, val_data = data_[train_index], data_[val_index]
        train_anno, val_anno = anno[train_index], anno[val_index]

        # Build and compile the model
        model = buildModel_Light_U_net(input_dim=(256, 256, 3))
        model_checkpoint = ModelCheckpoint(f'checkpoints/Light_U_Net_centroids_fold{fold}_{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}.hdf5', 
                                           monitor='loss', save_best_only=True)
        model.summary()
        
        # Learning rate scheduler
        change_lr = LearningRateScheduler(step_decay)

        # Data augmentation configuration
        datagen = ImageDataGenerator(
            featurewise_center=False,  
            samplewise_center=False,
            featurewise_std_normalization=False,  
            samplewise_std_normalization=False,
            zca_whitening=False,  
            rotation_range=30,  
            width_shift_range=0.3,  
            height_shift_range=0.3,  
            zoom_range=0.3,
            shear_range=0.,
            horizontal_flip=True,  
            vertical_flip=True, 
            fill_mode='constant',
            # dim_ordering='tf'
        )
        start_time = time.time()

        # Fit the model on the current fold's training data
        history = model.fit_generator(
            datagen.flow(train_data, train_anno, batch_size=4),
            steps_per_epoch=train_data.shape[0]//4 ,  # Calculate steps per epoch based on batch size
            epochs=50,
            callbacks=[model_checkpoint, change_lr]
        )
        end_time = time.time()
        duration = end_time - start_time  # duration in seconds

        # Print training duration
        print(f"Training duration: {duration:.2f} seconds")
        print(f"Training duration: {duration / 60:.2f} minutes")
        durations.append(duration)
        # Store fold result (you can also evaluate on validation data if needed)
        fold_results.append(history.history)
        fold += 1

    return fold_results , durations

# %% [markdown]
# # Centroids

# %%
base_address= 'C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper'
input_image_folder= base_address+ '/real_dataset/data_80_dics/'

label_center_folder= base_address+ '/real_dataset/data_80_dots/'

# %%
def load_images_from_folder(input_image_folder , label_image_folder , type_of_label , factor= 100):
    images = []
    labels = []
    dots_count=[]
    file_names=[]
    for filename in os.listdir(input_image_folder):
        img_path = os.path.join(input_image_folder, filename)
        label_path = os.path.join(label_image_folder, filename[:-8] + 'dots.png')

        # print("input", img_path)
        # print("lable", label_path)
        file_names.append(filename)
        img = cv2.imread(img_path)  # Read as grayscale
        label_image = cv2.imread( label_path )
        # plt.imshow(label_image)
        # plt.axis('off')  # Turn off axis numbers and ticks
        # plt.show()        
        label_image1= label_image
        if type_of_label== 'center':
          label_image= factor * (label_image[:,:,2] > 0)
        label_image = np.expand_dims(label_image, axis=-1)
        # print(label_image.shape)  # Output: (256, 256, 1)
        # print(np.unique(label_image))
        dots_count.append(str(np.sum(label_image1[:,:,2] > 0)))

        if img is not None and label_image is not None :
            # print(img.shape , np.unique(label_image) )
            images.append(img)
            labels.append(label_image)
    return np.array(images), np.array(labels) , np.array(dots_count) , np.array(file_names)

# %%
data, anno_centroids , counts , centroids_file_names = load_images_from_folder(input_image_folder , label_center_folder , "center")
print(f'Loaded {len(data)} cell images and  {len(anno_centroids)} regions label images.')
# Out:
# Loaded 80 cell images and  80 regions label images.

# %% [markdown]
# # train

# %%
from tensorflow.keras import backend as K
import gc

def clear_memory():
    K.clear_session()
    gc.collect()
clear_memory()

# %%
historys_center , durations = train_with_kfold(data, anno_centroids)
# Out:
# Training fold 1/5
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1728        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36864       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 64) 36864       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 36864       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   36864       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36864       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   36864       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36864       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 64, 64, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 128)  0           up_sampling2d[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 64)   73728       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 64)   36864       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 64) 0           activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           up_sampling2d_1[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 64) 256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 64) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 64) 36864       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 64) 256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 64) 0           activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 128 0           up_sampling2d_2[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 64) 73728       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 256, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 256, 256, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_12[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 5s 55ms/step - loss: 52.3233
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.9493
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.9468
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 79ms/step - loss: 51.9521
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9417
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.9348
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9374
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.9334
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9309
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 62ms/step - loss: 51.9310
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.9295
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9282
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.9281
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.9288
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 63ms/step - loss: 51.9270
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 62ms/step - loss: 51.9267
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.9258
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 62ms/step - loss: 51.9231
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.9232
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.9232
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9225
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.9234
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9225
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.9223
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.9228
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9222
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 51ms/step - loss: 51.9226
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9222
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9219
# Epoch 30/50
# Learning rate for epoch 30 is 0.0001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9220
# Epoch 31/50
# Learning rate for epoch 31 is 0.0001.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9216
# Epoch 32/50
# Learning rate for epoch 32 is 0.0001.
# 16/16 [==============================] - 1s 51ms/step - loss: 51.9218
# Epoch 33/50
# Learning rate for epoch 33 is 1e-05.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9224
# Epoch 34/50
# Learning rate for epoch 34 is 1e-05.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9217
# Epoch 35/50
# Learning rate for epoch 35 is 1e-05.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.9212
# Epoch 36/50
# Learning rate for epoch 36 is 1e-05.
# 16/16 [==============================] - 1s 51ms/step - loss: 51.9209
# Epoch 37/50
# Learning rate for epoch 37 is 1e-05.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9214
# Epoch 38/50
# Learning rate for epoch 38 is 1e-05.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9218
# Epoch 39/50
# Learning rate for epoch 39 is 1e-05.
# 16/16 [==============================] - 1s 51ms/step - loss: 51.9216
# Epoch 40/50
# Learning rate for epoch 40 is 1e-05.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9212
# Epoch 41/50
# Learning rate for epoch 41 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 51.9214
# Epoch 42/50
# Learning rate for epoch 42 is 1e-05.
# 16/16 [==============================] - 1s 51ms/step - loss: 51.9213
# Epoch 43/50
# Learning rate for epoch 43 is 1e-05.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9216
# Epoch 44/50
# Learning rate for epoch 44 is 1e-05.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9217
# Epoch 45/50
# Learning rate for epoch 45 is 1e-05.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9214
# Epoch 46/50
# Learning rate for epoch 46 is 1e-05.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9212
# Epoch 47/50
# Learning rate for epoch 47 is 1e-05.
# 16/16 [==============================] - 1s 50ms/step - loss: 51.9213
# Epoch 48/50
# Learning rate for epoch 48 is 1e-05.
# 16/16 [==============================] - 1s 51ms/step - loss: 51.9213
# Epoch 49/50
# Learning rate for epoch 49 is 0.001.
# 16/16 [==============================] - 1s 51ms/step - loss: 51.9265
# Epoch 50/50
# Learning rate for epoch 50 is 0.001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.9246
# Training duration: 51.73 seconds
# Training duration: 0.86 minutes
# Training fold 2/5
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 64) 1728        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 256, 256, 64) 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 256, 256, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 64) 36864       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256, 256, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 256, 256, 64) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 36864       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 36864       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 128, 128, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   36864       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 64)   36864       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 64)   36864       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 64)   36864       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 64)   0           activation_20[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 128)  0           up_sampling2d_3[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   73728       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 64, 64, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 64)   36864       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64) 0           activation_22[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 128 0           up_sampling2d_4[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 64) 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 128, 128, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 36864       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 128, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 128, 128, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 64) 0           activation_24[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 256, 128 0           up_sampling2d_5[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 64) 73728       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256, 256, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 256, 256, 64) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_25[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 52.6030
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.9046
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 51.9000
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.8924
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.8780
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.8809
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.8750
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.8726
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.8738
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.8693
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.8658
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.8676
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.8663
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.8653
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.8640
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 71ms/step - loss: 51.8640
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 72ms/step - loss: 51.8606
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 62ms/step - loss: 51.8602
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 66ms/step - loss: 51.8599
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.8597
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.8588
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.8590
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.8592
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.8591
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.8585
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.8590
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.8588
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.8589
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.8581
# Epoch 30/50
# Learning rate for epoch 30 is 0.0001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.8582
# Epoch 31/50
# Learning rate for epoch 31 is 0.0001.
# 16/16 [==============================] - 1s 66ms/step - loss: 51.8580
# Epoch 32/50
# Learning rate for epoch 32 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.8583
# Epoch 33/50
# Learning rate for epoch 33 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.8576
# Epoch 34/50
# Learning rate for epoch 34 is 1e-05.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.8579
# Epoch 35/50
# Learning rate for epoch 35 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.8583
# Epoch 36/50
# Learning rate for epoch 36 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.8577
# Epoch 37/50
# Learning rate for epoch 37 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.8576
# Epoch 38/50
# Learning rate for epoch 38 is 1e-05.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.8577
# Epoch 39/50
# Learning rate for epoch 39 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.8576
# Epoch 40/50
# Learning rate for epoch 40 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.8573
# Epoch 41/50
# Learning rate for epoch 41 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.8572
# Epoch 42/50
# Learning rate for epoch 42 is 1e-05.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.8577
# Epoch 43/50
# Learning rate for epoch 43 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.8571
# Epoch 44/50
# Learning rate for epoch 44 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 51.8579
# Epoch 45/50
# Learning rate for epoch 45 is 1e-05.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.8580
# Epoch 46/50
# Learning rate for epoch 46 is 1e-05.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.8580
# Epoch 47/50
# Learning rate for epoch 47 is 1e-05.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.8573
# Epoch 48/50
# Learning rate for epoch 48 is 1e-05.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.8578
# Epoch 49/50
# Learning rate for epoch 49 is 0.001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.8630
# Epoch 50/50
# Learning rate for epoch 50 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.8622
# Training duration: 50.42 seconds
# Training duration: 0.84 minutes
# Training fold 3/5
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 64) 1728        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 256, 256, 64) 256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 256, 256, 64) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 64) 36864       activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 256, 256, 64) 256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 256, 256, 64) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 64) 36864       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 64) 256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 128, 128, 64) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 128, 128, 64) 36864       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 128, 128, 64) 256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 128, 128, 64) 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 64)   36864       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 64, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 64)   36864       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 64, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 64)   36864       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 64)   36864       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 64)   0           activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           up_sampling2d_6[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 64)   73728       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 64)   36864       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 64, 64, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 64) 0           activation_35[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 128 0           up_sampling2d_7[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 128, 64) 256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 128, 128, 64) 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 64) 36864       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128, 128, 64) 256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 128, 128, 64) 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 256, 256, 64) 0           activation_37[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 128 0           up_sampling2d_8[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 64) 73728       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 256, 256, 64) 256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 256, 256, 64) 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_38[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 52.4463
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 52.0270
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 52.0182
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 52.0117
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 52.0047
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 52.0031
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 62ms/step - loss: 52.0026
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.9984
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.9970
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 66ms/step - loss: 51.9940
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 69ms/step - loss: 51.9938
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.9926
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.9910
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.9900
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.9898
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.9887
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9860
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 62ms/step - loss: 51.9849
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9851
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.9847
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 63ms/step - loss: 51.9846
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 66ms/step - loss: 51.9849
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.9845
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.9842
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9854
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 68ms/step - loss: 51.9846
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.9845
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 60ms/step - loss: 51.9842
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.9840
# Epoch 30/50
# Learning rate for epoch 30 is 0.0001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.9842
# Epoch 31/50
# Learning rate for epoch 31 is 0.0001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.9844
# Epoch 32/50
# Learning rate for epoch 32 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.9834
# Epoch 33/50
# Learning rate for epoch 33 is 1e-05.
# ...
# batch_normalization_52 (BatchNo (None, 256, 256, 64) 256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 256, 256, 64) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 64) 36864       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 256, 256, 64) 256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 256, 256, 64) 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 128, 128, 64) 0           activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 128, 128, 64) 36864       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 128, 128, 64) 256         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 128, 128, 64) 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 128, 128, 64) 36864       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 128, 128, 64) 256         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 128, 128, 64) 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 64, 64, 64)   0           activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 64)   36864       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64, 64, 64)   256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 64, 64, 64)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 64)   36864       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 64, 64, 64)   256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 64, 64, 64)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 32, 32, 64)   0           activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 64)   36864       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 64)   256         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 64)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 64)   36864       activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 64)   256         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 64)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 64, 64, 64)   0           activation_59[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 64, 64, 128)  0           up_sampling2d_12[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 64)   73728       concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 64, 64, 64)   256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 64, 64, 64)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 64)   36864       activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 64)   256         conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 64, 64, 64)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 128, 128, 64) 0           activation_61[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 128, 128, 128 0           up_sampling2d_13[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 128, 128, 64) 256         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 128, 128, 64) 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 128, 128, 64) 36864       activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 128, 128, 64) 256         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 128, 128, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 256, 256, 64) 0           activation_63[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 256, 256, 128 0           up_sampling2d_14[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 256, 256, 64) 73728       concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 256, 256, 64) 256         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 256, 256, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_64[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 1s 63ms/step - loss: 51.6848
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.1139
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.1012
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.1072
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.0904
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0953
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.0887
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.0876
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.0830
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.0811
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.0834
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 62ms/step - loss: 51.0798
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.0819
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0774
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0803
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.0794
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.0745
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.0734
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 51.0737
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.0737
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.0738
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.0736
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 65ms/step - loss: 51.0732
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.0732
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 61ms/step - loss: 51.0734
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.0733
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 68ms/step - loss: 51.0733
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 63ms/step - loss: 51.0723
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 62ms/step - loss: 51.0731
# Epoch 30/50
# Learning rate for epoch 30 is 0.0001.
# 16/16 [==============================] - 1s 59ms/step - loss: 51.0735
# Epoch 31/50
# Learning rate for epoch 31 is 0.0001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0731
# Epoch 32/50
# Learning rate for epoch 32 is 0.0001.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.0726
# Epoch 33/50
# Learning rate for epoch 33 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.0725
# Epoch 34/50
# Learning rate for epoch 34 is 1e-05.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.0721
# Epoch 35/50
# Learning rate for epoch 35 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.0723
# Epoch 36/50
# Learning rate for epoch 36 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0720
# Epoch 37/50
# Learning rate for epoch 37 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 51.0725
# Epoch 38/50
# Learning rate for epoch 38 is 1e-05.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.0720
# Epoch 39/50
# Learning rate for epoch 39 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.0730
# Epoch 40/50
# Learning rate for epoch 40 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 51.0725
# Epoch 41/50
# Learning rate for epoch 41 is 1e-05.
# 16/16 [==============================] - 1s 57ms/step - loss: 51.0728
# Epoch 42/50
# Learning rate for epoch 42 is 1e-05.
# 16/16 [==============================] - 1s 63ms/step - loss: 51.0725
# Epoch 43/50
# Learning rate for epoch 43 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0721
# Epoch 44/50
# Learning rate for epoch 44 is 1e-05.
# 16/16 [==============================] - 1s 56ms/step - loss: 51.0725
# Epoch 45/50
# Learning rate for epoch 45 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0724
# Epoch 46/50
# Learning rate for epoch 46 is 1e-05.
# 16/16 [==============================] - 1s 58ms/step - loss: 51.0721
# Epoch 47/50
# Learning rate for epoch 47 is 1e-05.
# 16/16 [==============================] - 1s 52ms/step - loss: 51.0723
# Epoch 48/50
# Learning rate for epoch 48 is 1e-05.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0717
# Epoch 49/50
# Learning rate for epoch 49 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 51.0777
# Epoch 50/50
# Learning rate for epoch 50 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 51.0768
# Training duration: 48.93 seconds
# Training duration: 0.82 minutes

# %% [markdown]
# # loss chart

# %%
def plot_loss(fold_results):
    """
    Plot the training loss curves for each fold.
    """
    plt.figure(figsize=(10, 6))

    # Iterate through each fold's history
    for fold_idx, history in enumerate(fold_results, 1):
        loss = history['loss']
        plt.plot(loss, label=f'Fold {fold_idx}')
    
    # Add title and labels
    plt.title('Training Loss per Fold')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_average_training_time(durations):
    """
    Plot the average training time for each fold.
    """
    avg_time = np.mean(durations)
    plt.figure(figsize=(10, 6))
    plt.bar(range(1, len(durations) + 1), durations, color='b', alpha=0.6)
    
    # Plot the average line
    plt.axhline(avg_time, color='r', linestyle='--', label=f'Avg Training Time: {avg_time/60:.2f} min')
    
    # Add title and labels
    plt.title('Training Time per Fold')
    plt.xlabel('Fold')
    plt.ylabel('Training Time (seconds)')
    plt.legend()
    plt.show()

def summarize_results(fold_results, durations):
    """
    Summarize the results by plotting loss curves and average training time.
    """
    # Plot the loss curves for all folds
    plot_loss(fold_results)
    
    # Plot the average training time for all folds
    plot_average_training_time(durations)

# %%
import matplotlib.pyplot as plt

summarize_results(historys_center, durations)

# %% [markdown]
# # Light-U-Net Regions

# %%
def step_decay(epoch):
    step = 16
    lrate=1e0
    num =  epoch // step
    if num % 3 == 0:
        lrate = 1e-3
    elif num % 3 == 1:
        lrate = 1e-4
    else:
        lrate = 1e-5
        #lrate = initial_lrate * 1/(1 + decay * (epoch - num * step))
    print('Learning rate for epoch {} is {}.'.format(epoch+1, lrate))
    return float(lrate)

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

tf.config.run_functions_eagerly(True)
np.float = float
def train_with_kfold(data, anno, n_splits=5):
    # Step 1: Preprocessing data (Standardization)
    mean = np.mean(data)
    std = np.std(data)
    data_ = (data - mean) / std

    # Initialize KFold
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    fold_results = []  # To store results for each fold
    durations=[]
    fold = 1

    for train_index, val_index in kf.split(data_):
        print(f"Training fold {fold}/{n_splits}")

        # Split data into training and validation sets based on the current fold
        train_data, val_data = data_[train_index], data_[val_index]
        train_anno, val_anno = anno[train_index], anno[val_index]

        # Build and compile the model
        model = buildModel_Light_U_net(input_dim=(256, 256, 3))
        model_checkpoint = ModelCheckpoint(f'checkpoints/Light_U_Net_regions_fold{fold}_{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}.hdf5', 
                                           monitor='loss', save_best_only=True)
        model.summary()
        
        # Learning rate scheduler
        change_lr = LearningRateScheduler(step_decay)

        # Data augmentation configuration
        datagen = ImageDataGenerator(
            featurewise_center=False,  
            samplewise_center=False,
            featurewise_std_normalization=False,  
            samplewise_std_normalization=False,
            zca_whitening=False,  
            rotation_range=30,  
            width_shift_range=0.3,  
            height_shift_range=0.3,  
            zoom_range=0.3,
            shear_range=0.,
            horizontal_flip=True,  
            vertical_flip=True, 
            fill_mode='constant',
            # dim_ordering='tf'
        )
        start_time = time.time()

        # Fit the model on the current fold's training data
        history = model.fit_generator(
            datagen.flow(train_data, train_anno, batch_size=4),
            steps_per_epoch=train_data.shape[0]//4 ,  # Calculate steps per epoch based on batch size
            epochs=50,
            callbacks=[model_checkpoint, change_lr]
        )
        end_time = time.time()
        duration = end_time - start_time  # duration in seconds

        # Print training duration
        print(f"Training duration: {duration:.2f} seconds")
        print(f"Training duration: {duration / 60:.2f} minutes")
        durations.append(duration)
        # Store fold result (you can also evaluate on validation data if needed)
        fold_results.append(history.history)
        fold += 1

    return fold_results , durations

# %% [markdown]
# # Regions

# %%
def load_images_from_folder(input_image_folder , label_image_folder , type_of_label , factor= 100):
    images = []
    labels = []
    file_names=[]
    for filename in os.listdir(input_image_folder):

        img_path = os.path.join(input_image_folder, filename)
        label_path = os.path.join(label_image_folder, filename[:-8] + 'regions.png')
        # print(img_path)
        # print(label_path)
        img = cv2.imread(img_path)  # Read as grayscale
        label_image = cv2.imread( label_path )
        # plt.imshow(label_image)
        # plt.axis('off')  # Turn off axis numbers and ticks
        # plt.show()
        if type_of_label== 'center':
          label_image= factor * (label_image[:,:,2] > 0)
        
        label_image = label_image[:,:,0]
        label_image = np.expand_dims(label_image, axis=-1)
        # print(label_image.shape)  # Output: (256, 256, 1)
        # print(np.unique(label_image))

        if img is not None and label_image is not None :
            # print(img.shape )
            # print(img.shape , label_image)
            images.append(img)
            labels.append(label_image)
            file_names.append(filename)

    return np.array(images), np.array(labels) , np.array(file_names)

# %%
base_address= 'C:/Users/narges/PycharmProjects3/pythonProject3/IEEE_transaction_paper'
input_image_folder=base_address+ '/real_dataset/data_80_dics/'

label_region_folder=base_address+ '/real_dataset/data_80_regions/'

# %%
data, anno_regions  ,region_file_names = load_images_from_folder(input_image_folder , label_region_folder , "region")
print(f'Loaded {len(data)} cell images and  {len(anno_regions)} regions label images.')
# Out:
# Loaded 80 cell images and  80 regions label images.

# %% [markdown]
# # train

# %%
history_regions ,durations = train_with_kfold(data, anno_regions)
# Out:
# Training fold 1/5
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 256, 256, 64) 1728        input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 256, 256, 64) 256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 256, 256, 64) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 256, 256, 64) 36864       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 256, 256, 64) 256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 256, 256, 64) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 128, 128, 64) 0           activation_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 128, 128, 64) 36864       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 128, 128, 64) 256         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 128, 128, 64) 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 128, 128, 64) 36864       activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 128, 128, 64) 256         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 128, 128, 64) 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 64, 64, 64)   0           activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 64, 64)   36864       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 64, 64, 64)   256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 64, 64, 64)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 64, 64, 64)   36864       activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 64, 64, 64)   256         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 64, 64, 64)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 32, 32, 64)   0           activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 64)   36864       max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 64)   256         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 32, 32, 64)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 64)   36864       activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 32, 32, 64)   256         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 32, 32, 64)   0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 64, 64, 64)   0           activation_72[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 128)  0           up_sampling2d_15[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 64, 64)   73728       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 64, 64, 64)   256         conv2d_73[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 64, 64, 64)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 64, 64)   36864       activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 64, 64, 64)   256         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 64, 64, 64)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 128, 128, 64) 0           activation_74[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 128, 128, 128 0           up_sampling2d_16[0][0]
#                                                                  activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 128, 128, 64) 256         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 128, 128, 64) 0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 128, 128, 64) 36864       activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 128, 128, 64) 256         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 128, 128, 64) 0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 256, 256, 64) 0           activation_76[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 256, 256, 128 0           up_sampling2d_17[0][0]
#                                                                  activation_66[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 256, 256, 64) 73728       concatenate_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 256, 256, 64) 256         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 256, 256, 64) 0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_77[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 39892.9922
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 57ms/step - loss: 39557.2852
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 39366.2422
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 39212.6289
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 39046.6836
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 38886.1211
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 64ms/step - loss: 38714.4922
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38539.8398
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 38350.4727
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38156.6523
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37941.5781
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37717.0742
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37486.0508
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 37258.1055
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36998.3594
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 36738.5547
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 64ms/step - loss: 36582.2695
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36529.2383
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36496.8438
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36456.6953
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36429.0039
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 59ms/step - loss: 36415.9883
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36370.2148
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36334.2188
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36327.0195
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36298.8438
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36268.1836
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 36232.2227
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36220.4805
# Epoch 30/50
# Learning rate for epoch 30 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36171.9727
# Epoch 31/50
# Learning rate for epoch 31 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36153.6602
# Epoch 32/50
# Learning rate for epoch 32 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36117.8477
# Epoch 33/50
# Learning rate for epoch 33 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 36117.3711
# Epoch 34/50
# Learning rate for epoch 34 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 36113.8438
# Epoch 35/50
# Learning rate for epoch 35 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 36107.8633
# Epoch 36/50
# Learning rate for epoch 36 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 36121.6641
# Epoch 37/50
# Learning rate for epoch 37 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 36096.1602
# Epoch 38/50
# Learning rate for epoch 38 is 1e-05.
# 16/16 [==============================] - 1s 60ms/step - loss: 36081.3672
# Epoch 39/50
# Learning rate for epoch 39 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 36098.4414
# Epoch 40/50
# Learning rate for epoch 40 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 36091.1367
# Epoch 41/50
# Learning rate for epoch 41 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 36072.0000
# Epoch 42/50
# Learning rate for epoch 42 is 1e-05.
# 16/16 [==============================] - 1s 56ms/step - loss: 36090.4648
# Epoch 43/50
# Learning rate for epoch 43 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 36080.4922
# Epoch 44/50
# Learning rate for epoch 44 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 36071.4453
# Epoch 45/50
# Learning rate for epoch 45 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 36075.3633
# Epoch 46/50
# Learning rate for epoch 46 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 36080.1797
# Epoch 47/50
# Learning rate for epoch 47 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 36054.0781
# Epoch 48/50
# Learning rate for epoch 48 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 36060.5039
# Epoch 49/50
# Learning rate for epoch 49 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35975.0312
# Epoch 50/50
# Learning rate for epoch 50 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35704.4219
# Training duration: 48.25 seconds
# Training duration: 0.80 minutes
# Training fold 2/5
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 256, 256, 64) 1728        input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 256, 256, 64) 256         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 256, 256, 64) 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 256, 256, 64) 36864       activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 256, 256, 64) 256         conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 256, 256, 64) 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 128, 128, 64) 0           activation_79[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 128, 128, 64) 36864       max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 128, 128, 64) 256         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 128, 128, 64) 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 128, 128, 64) 36864       activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 128, 128, 64) 256         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 128, 128, 64) 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 64, 64, 64)   0           activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 64, 64, 64)   36864       max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 64, 64, 64)   256         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 64, 64, 64)   0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 64, 64, 64)   36864       activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 64, 64, 64)   256         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 64, 64, 64)   0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 32, 32, 64)   0           activation_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 32, 64)   36864       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 32, 32, 64)   256         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 32, 32, 64)   0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 64)   36864       activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 32, 32, 64)   256         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 32, 32, 64)   0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 64, 64, 64)   0           activation_85[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 64, 64, 128)  0           up_sampling2d_18[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 64, 64, 64)   73728       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 64, 64, 64)   256         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 64, 64, 64)   0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 64, 64, 64)   36864       activation_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 64, 64, 64)   256         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 64, 64, 64)   0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 128, 128, 64) 0           activation_87[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 128, 128, 128 0           up_sampling2d_19[0][0]
#                                                                  activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 128, 128, 64) 73728       concatenate_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 128, 128, 64) 256         conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 128, 128, 64) 0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 128, 128, 64) 36864       activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 128, 128, 64) 256         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 128, 128, 64) 0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 256, 256, 64) 0           activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 256, 256, 128 0           up_sampling2d_20[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 256, 256, 64) 73728       concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 256, 256, 64) 256         conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 256, 256, 64) 0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_90[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 39563.5430
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 39245.7969
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 39047.2305
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 60ms/step - loss: 38885.1836
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38671.5508
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38488.2227
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 38286.8906
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 38084.5195
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 37876.0820
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37631.6914
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 37406.9141
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 37164.8008
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36896.6250
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36627.0898
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36343.3555
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36062.8164
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35869.9336
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 58ms/step - loss: 35846.9219
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 35791.4453
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35774.6836
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35746.7070
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35721.1445
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35689.9453
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35663.1445
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35626.7852
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35601.4258
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35549.5273
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35533.8516
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 35484.9492
# Epoch 30/50
# Learning rate for epoch 30 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35446.8008
# Epoch 31/50
# Learning rate for epoch 31 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35438.5938
# Epoch 32/50
# Learning rate for epoch 32 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35407.1602
# Epoch 33/50
# Learning rate for epoch 33 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35362.6484
# Epoch 34/50
# Learning rate for epoch 34 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 35383.3516
# Epoch 35/50
# Learning rate for epoch 35 is 1e-05.
# 16/16 [==============================] - 1s 58ms/step - loss: 35369.8594
# Epoch 36/50
# Learning rate for epoch 36 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 35357.7344
# Epoch 37/50
# Learning rate for epoch 37 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 35373.2539
# Epoch 38/50
# Learning rate for epoch 38 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35363.7422
# Epoch 39/50
# Learning rate for epoch 39 is 1e-05.
# 16/16 [==============================] - 1s 56ms/step - loss: 35370.9570
# Epoch 40/50
# Learning rate for epoch 40 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35354.7578
# Epoch 41/50
# Learning rate for epoch 41 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35341.4336
# Epoch 42/50
# Learning rate for epoch 42 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35363.6055
# Epoch 43/50
# Learning rate for epoch 43 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35356.1094
# Epoch 44/50
# Learning rate for epoch 44 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35348.9141
# Epoch 45/50
# Learning rate for epoch 45 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35337.8633
# Epoch 46/50
# Learning rate for epoch 46 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 35342.6602
# Epoch 47/50
# Learning rate for epoch 47 is 1e-05.
# 16/16 [==============================] - 1s 58ms/step - loss: 35302.9102
# Epoch 48/50
# Learning rate for epoch 48 is 1e-05.
# 16/16 [==============================] - 1s 54ms/step - loss: 35306.0000
# Epoch 49/50
# Learning rate for epoch 49 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 35234.0078
# Epoch 50/50
# Learning rate for epoch 50 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 34904.0703
# Training duration: 47.44 seconds
# Training duration: 0.79 minutes
# Training fold 3/5
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 256, 256, 64) 1728        input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 256, 256, 64) 256         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 256, 256, 64) 0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 256, 256, 64) 36864       activation_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 256, 256, 64) 256         conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 256, 256, 64) 0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 128, 128, 64) 0           activation_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 128, 128, 64) 36864       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 128, 128, 64) 256         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 128, 128, 64) 0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 128, 128, 64) 36864       activation_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 128, 128, 64) 256         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 128, 128, 64) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 64, 64, 64)   0           activation_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 64, 64, 64)   36864       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 64, 64, 64)   256         conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 64, 64, 64)   0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 64, 64, 64)   36864       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 64, 64, 64)   256         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 64, 64, 64)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 32, 32, 64)   0           activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 32, 32, 64)   36864       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 32, 32, 64)   256         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 32, 32, 64)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 32, 32, 64)   36864       activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 32, 32, 64)   256         conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 32, 32, 64)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 64, 64, 64)   0           activation_98[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 64, 64, 128)  0           up_sampling2d_21[0][0]
#                                                                  activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 64, 64, 64)   73728       concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 64, 64, 64)   256         conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 64, 64, 64)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 64, 64, 64)   36864       activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 64, 64, 64)   256         conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 64, 64, 64)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 128, 128, 64) 0           activation_100[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 128, 128, 128 0           up_sampling2d_22[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 128, 128, 64) 73728       concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 128, 128, 64) 256         conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 128, 128, 64) 0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 128, 128, 64) 36864       activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 128, 128, 64) 256         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 128, 128, 64) 0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 256, 256, 64) 0           activation_102[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 256, 256, 128 0           up_sampling2d_23[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 256, 256, 64) 73728       concatenate_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 256, 256, 64) 256         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 256, 256, 64) 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_103[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 1s 59ms/step - loss: 39794.2852
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 39471.6211
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 39287.4141
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 39114.1953
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 38953.9688
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 38778.6641
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 38574.2305
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 38379.7227
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38166.9023
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 37964.1094
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37716.5625
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37493.0156
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37255.6016
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 36987.7266
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36723.9609
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36453.7891
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 62ms/step - loss: 36269.4648
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 55ms/step - loss: 36230.2266
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36213.0117
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36178.8633
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36144.9492
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 55ms/step - loss: 36109.2227
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36063.9062
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36047.5234
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36022.4258
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35990.0703
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35963.7461
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35923.2734
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 56ms/step - loss: 35893.9062
# Epoch 30/50
# ...
# activation_117 (Activation)     (None, 256, 256, 64) 0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 256, 256, 64) 36864       activation_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 256, 256, 64) 256         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 256, 256, 64) 0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 128, 128, 64) 0           activation_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 128, 128, 64) 36864       max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 128, 128, 64) 256         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 128, 128, 64) 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 128, 128, 64) 36864       activation_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 128, 128, 64) 256         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 128, 128, 64) 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 64, 64, 64)   0           activation_120[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 64, 64, 64)   36864       max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 64, 64, 64)   256         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 64, 64, 64)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 64, 64, 64)   36864       activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 64, 64, 64)   256         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 64, 64, 64)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 32, 32, 64)   0           activation_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 32, 32, 64)   36864       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 32, 32, 64)   256         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 32, 32, 64)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 32, 32, 64)   36864       activation_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 32, 32, 64)   256         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 32, 32, 64)   0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_27 (UpSampling2D) (None, 64, 64, 64)   0           activation_124[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 64, 64, 128)  0           up_sampling2d_27[0][0]
#                                                                  activation_122[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 64, 64, 64)   73728       concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 64, 64, 64)   256         conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 64, 64, 64)   0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 64, 64, 64)   36864       activation_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 64, 64, 64)   256         conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 64, 64, 64)   0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_28 (UpSampling2D) (None, 128, 128, 64) 0           activation_126[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 128, 128, 128 0           up_sampling2d_28[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 128, 128, 64) 73728       concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 128, 128, 64) 256         conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 128, 128, 64) 0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 128, 128, 64) 36864       activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 128, 128, 64) 256         conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 128, 128, 64) 0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_29 (UpSampling2D) (None, 256, 256, 64) 0           activation_128[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 256, 256, 128 0           up_sampling2d_29[0][0]
#                                                                  activation_118[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 256, 256, 64) 73728       concatenate_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 256, 256, 64) 256         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 256, 256, 64) 0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# pred (Conv2D)                   (None, 256, 256, 1)  64          activation_129[0][0]
# ==================================================================================================
# Total params: 558,080
# Trainable params: 556,416
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Epoch 1/50
# Learning rate for epoch 1 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 39318.9570
# Epoch 2/50
# Learning rate for epoch 2 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 39006.3750
# Epoch 3/50
# Learning rate for epoch 3 is 0.001.
# 16/16 [==============================] - 1s 56ms/step - loss: 38825.5664
# Epoch 4/50
# Learning rate for epoch 4 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38666.5703
# Epoch 5/50
# Learning rate for epoch 5 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38494.2773
# Epoch 6/50
# Learning rate for epoch 6 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 38308.1953
# Epoch 7/50
# Learning rate for epoch 7 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 38120.0352
# Epoch 8/50
# Learning rate for epoch 8 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37938.0508
# Epoch 9/50
# Learning rate for epoch 9 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37739.8008
# Epoch 10/50
# Learning rate for epoch 10 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 37514.6289
# Epoch 11/50
# Learning rate for epoch 11 is 0.001.
# 16/16 [==============================] - 1s 61ms/step - loss: 37295.2695
# Epoch 12/50
# Learning rate for epoch 12 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 37078.1680
# Epoch 13/50
# Learning rate for epoch 13 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36846.0430
# Epoch 14/50
# Learning rate for epoch 14 is 0.001.
# 16/16 [==============================] - 1s 54ms/step - loss: 36594.1055
# Epoch 15/50
# Learning rate for epoch 15 is 0.001.
# 16/16 [==============================] - 1s 55ms/step - loss: 36337.4922
# Epoch 16/50
# Learning rate for epoch 16 is 0.001.
# 16/16 [==============================] - 1s 53ms/step - loss: 36085.9492
# Epoch 17/50
# Learning rate for epoch 17 is 0.0001.
# 16/16 [==============================] - 1s 54ms/step - loss: 35907.0312
# Epoch 18/50
# Learning rate for epoch 18 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35874.6484
# Epoch 19/50
# Learning rate for epoch 19 is 0.0001.
# 16/16 [==============================] - 1s 55ms/step - loss: 35836.0742
# Epoch 20/50
# Learning rate for epoch 20 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35811.5664
# Epoch 21/50
# Learning rate for epoch 21 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35779.7188
# Epoch 22/50
# Learning rate for epoch 22 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35757.9258
# Epoch 23/50
# Learning rate for epoch 23 is 0.0001.
# 16/16 [==============================] - 1s 75ms/step - loss: 35728.9531
# Epoch 24/50
# Learning rate for epoch 24 is 0.0001.
# 16/16 [==============================] - 1s 81ms/step - loss: 35694.9141
# Epoch 25/50
# Learning rate for epoch 25 is 0.0001.
# 16/16 [==============================] - 1s 83ms/step - loss: 35674.9453
# Epoch 26/50
# Learning rate for epoch 26 is 0.0001.
# 16/16 [==============================] - 1s 84ms/step - loss: 35637.3750
# Epoch 27/50
# Learning rate for epoch 27 is 0.0001.
# 16/16 [==============================] - 1s 86ms/step - loss: 35618.9688
# Epoch 28/50
# Learning rate for epoch 28 is 0.0001.
# 16/16 [==============================] - 1s 84ms/step - loss: 35572.8633
# Epoch 29/50
# Learning rate for epoch 29 is 0.0001.
# 16/16 [==============================] - 1s 65ms/step - loss: 35557.5781
# Epoch 30/50
# Learning rate for epoch 30 is 0.0001.
# 16/16 [==============================] - 1s 60ms/step - loss: 35516.3281
# Epoch 31/50
# Learning rate for epoch 31 is 0.0001.
# 16/16 [==============================] - 1s 60ms/step - loss: 35476.5703
# Epoch 32/50
# Learning rate for epoch 32 is 0.0001.
# 16/16 [==============================] - 1s 53ms/step - loss: 35438.6016
# Epoch 33/50
# Learning rate for epoch 33 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35425.6992
# Epoch 34/50
# Learning rate for epoch 34 is 1e-05.
# 16/16 [==============================] - 1s 53ms/step - loss: 35423.8789
# Epoch 35/50
# Learning rate for epoch 35 is 1e-05.
# 16/16 [==============================] - 1s 70ms/step - loss: 35430.1328
# Epoch 36/50
# Learning rate for epoch 36 is 1e-05.
# 16/16 [==============================] - 1s 83ms/step - loss: 35412.6289
# Epoch 37/50
# Learning rate for epoch 37 is 1e-05.
# 16/16 [==============================] - 1s 81ms/step - loss: 35427.5195
# Epoch 38/50
# Learning rate for epoch 38 is 1e-05.
# 16/16 [==============================] - 1s 88ms/step - loss: 35400.1875
# Epoch 39/50
# Learning rate for epoch 39 is 1e-05.
# 16/16 [==============================] - 1s 84ms/step - loss: 35401.7852
# Epoch 40/50
# Learning rate for epoch 40 is 1e-05.
# 16/16 [==============================] - 1s 81ms/step - loss: 35405.1680
# Epoch 41/50
# Learning rate for epoch 41 is 1e-05.
# 16/16 [==============================] - 1s 69ms/step - loss: 35399.6562
# Epoch 42/50
# Learning rate for epoch 42 is 1e-05.
# 16/16 [==============================] - 1s 86ms/step - loss: 35420.3359
# Epoch 43/50
# Learning rate for epoch 43 is 1e-05.
# 16/16 [==============================] - 2s 93ms/step - loss: 35386.2656
# Epoch 44/50
# Learning rate for epoch 44 is 1e-05.
# 16/16 [==============================] - 1s 81ms/step - loss: 35388.5156
# Epoch 45/50
# Learning rate for epoch 45 is 1e-05.
# 16/16 [==============================] - 1s 79ms/step - loss: 35395.1445
# Epoch 46/50
# Learning rate for epoch 46 is 1e-05.
# 16/16 [==============================] - 1s 81ms/step - loss: 35387.7148
# Epoch 47/50
# Learning rate for epoch 47 is 1e-05.
# 16/16 [==============================] - 1s 83ms/step - loss: 35388.5273
# Epoch 48/50
# Learning rate for epoch 48 is 1e-05.
# 16/16 [==============================] - 1s 87ms/step - loss: 35372.2461
# Epoch 49/50
# Learning rate for epoch 49 is 0.001.
# 16/16 [==============================] - 1s 82ms/step - loss: 35311.8438
# Epoch 50/50
# Learning rate for epoch 50 is 0.001.
# 16/16 [==============================] - 1s 85ms/step - loss: 34997.1055
# Training duration: 58.78 seconds
# Training duration: 0.98 minutes

# %% [markdown]
# # loss chart

# %%
import matplotlib.pyplot as plt

summarize_results(history_regions, durations)
